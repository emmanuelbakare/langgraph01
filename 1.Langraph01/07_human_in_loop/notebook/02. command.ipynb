# %% [markdown]
# # Linking node with Command and goto

# %%
from langgraph.graph import StateGraph, END, START
from langgraph.types import Command
from typing import TypedDict

class AgentState(TypedDict):
    text: str

# %% [markdown]
# ### Create nodes and use goto to point from one node to the other

# %%
def node_a(state:AgentState):
    print("In node A" )
    
    return Command( # this updates the state dictionary
        goto="node_b",
        update={
            "text" : state['text'] + "a"
        }
    )

def node_b(state:AgentState):
    print("In Node B")
    return Command(
        goto="node_c",
        update={
            "text": state['text'] + "b"
        }
    )


def node_c(state:AgentState):
    print("In Node C" )

    return Command(
            goto=END,
        update={
            "text":state['text'] + "c",
        }
    )

# %%
graph = StateGraph(AgentState)
graph.add_node("node_a", node_a)
graph.add_node("node_b", node_b)
graph.add_node("node_c", node_c)
# graph.add_edge(START,"node_a")
graph.set_entry_point("node_a")

# the add_edges code is options since command as specified where the next node connects to
# you will however need it if you want the mermaid graph to be properly displayed virtually.
graph.add_edge("node_a","node_b")
graph.add_edge("node_b","node_c")
graph.add_edge("node_c", END)
app  = graph.compile()

# %%
result =app.invoke({ "text":"","count":0})
result
# Out:
# In node A
# In Node B
# In Node C
# {'text': 'abc'}
