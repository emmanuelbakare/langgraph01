# %% [markdown]
# # Reflection Test

# %%
from langchain_groq import ChatGroq
from dotenv import load_dotenv
from langgraph.graph import START, END, StateGraph, add_messages
from typing import TypedDict, List, Annotated
from langchain_core.messages import BaseMessage, HumanMessage, SystemMessage
from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder
# from langgraph.langgraph import MessagesState
load_dotenv()

llm = ChatGroq(model="llama-3.3-70b-versatile") 

class MyState(TypedDict):
    messages : Annotated[List[BaseMessage], add_messages]
    critique: str
    score: int

system_generate =  ChatPromptTemplate.from_messages([
    ("system"," you are an expert in generating tweet. Generate a tweet that is classy, a little witty and can definately go viral"),
    MessagesPlaceholder(variable_name="messages")
])

generation_chain = system_generate | llm

# def generation(state:MyState):
#     message = state['messages']
#     response = llm.invoke(message)
#     print("----- GENERATION QUERY------")
#     print(message)
#     return {
#     "messages":response.content
#     }

def generation(state:MyState):
    response =  generation_chain.invoke({
        "messages":
    })

    return {
     



graph = StateGraph(MyState)
graph.add_node(generation)

graph.add_edge(START, "generation")
graph.add_edge("generation", END)

app = graph.compile()

app

response = app.invoke ({
    "messages":[HumanMessage(content="tweet on Lagos hustle")]
})

print('------- RAW RESULT--------')
print(response["messages"])
print(); print()
print('------- FINAL RESULT--------')
print(response["messages"][-1].content)
# Out:
# ----- GENERATION QUERY------
# [HumanMessage(content='tweet on Lagos hustle', additional_kwargs={}, response_metadata={}, id='fef1ba4b-247c-4042-a6e7-83f411640be6')]
# ------- RAW RESULT--------
# [HumanMessage(content='tweet on Lagos hustle', additional_kwargs={}, response_metadata={}, id='fef1ba4b-247c-4042-a6e7-83f411640be6'), HumanMessage(content='"Waking up in Lagos means you\'re ready to hustle! From the traffic jams to the street markets, every day is a grind. But in this city, hustle is a way of life. Who else is pushing through the chaos to chase their dreams? #LagosHustle #GrindMode"', additional_kwargs={}, response_metadata={}, id='a8494697-d858-4874-97a5-ee78db687171')]
#
#
# ------- FINAL RESULT--------
# "Waking up in Lagos means you're ready to hustle! From the traffic jams to the street markets, every day is a grind. But in this city, hustle is a way of life. Who else is pushing through the chaos to chase their dreams? #LagosHustle #GrindMode"
