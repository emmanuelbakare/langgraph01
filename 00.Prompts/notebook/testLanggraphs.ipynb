# %%
from typing import TypedDict, List
from langgraph.graph import START, END, StateGraph
from langchain_core.messages import BaseMessage, SystemMessage,AIMessage, HumanMessage
from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder
from langchain_groq import ChatGroq
from dotenv import load_dotenv

load_dotenv()

llm = ChatGroq(model='llama-3.3-70b-versatile')

class MyState(TypedDict):
    messages: List[BaseMessage]

generation_prompt = ChatPromptTemplate.from_messages([
    ("system","You are a social media content creator and you generate great content on twitter"),
    MessagesPlaceholder(variable_name ="messages")
])

reflection_prompt = ChatPromptTemplate.from_messages([
    ('system','You are an expert social media critic and tweet developer. You help make tweet go viral.'),
    MessagesPlaceholder
])

def generate(state:MyState):
    chain = generation_prompt | llm
    response = chain.invoke({"messages": state["messages"]})
    return state["messages"] + [AIMessage(response.content)]

def reflect(state:MyState):
    

output = generate({
    "messages": [HumanMessage(content="write about Lagos Hustle")]
})
# print(output["messages"][-1].content)
print(output[-1].content)
# Out:
# [HumanMessage(content='Where is Kilimanjaro', additional_kwargs={}, response_metadata={}), AIMessage(content="Kilimanjaro is a majestic mountain located in Tanzania, East Africa. Specifically, it is situated in the Kilimanjaro National Park, near the town of Moshi, in the northern part of the country.\n\nKilimanjaro is a dormant volcano and the highest peak in Africa, standing at an impressive 5,895 meters (19,341 feet) above sea level. It is a prominent geological feature and a popular destination for hiking and climbing enthusiasts.\n\nFrom a geological perspective, Kilimanjaro is a fascinating mountain that was formed as a result of volcanic activity around 2-3 million years ago. The mountain is composed of three distinct volcanic cones: Kibo, Mawenzi, and Shira. The summit of Kibo is the highest point on the mountain and is covered in a thick layer of ice and snow.\n\nAs a geologist, I can tell you that Kilimanjaro is a unique and complex geological system that offers valuable in
# ...

# %%
output[-1].content
# Out:
# "Kilimanjaro is a majestic mountain located in Tanzania, East Africa. Specifically, it is situated in the Kilimanjaro National Park, near the town of Moshi, in the northern part of the country.\n\nKilimanjaro is a dormant volcano and the highest peak in Africa, standing at an impressive 5,895 meters (19,341 feet) above sea level. It is a prominent geological feature and a popular destination for hiking and climbing enthusiasts.\n\nFrom a geological perspective, Kilimanjaro is a fascinating mountain that was formed as a result of volcanic activity around 2-3 million years ago. The mountain is composed of three distinct volcanic cones: Kibo, Mawenzi, and Shira. The summit of Kibo is the highest point on the mountain and is covered in a thick layer of ice and snow.\n\nAs a geologist, I can tell you that Kilimanjaro is a unique and complex geological system that offers valuable insights into the Earth's history and the processes that shape our planet. The mountain's formation, evolution,
# ...
